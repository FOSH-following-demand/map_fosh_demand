# %%
#notebook to change the pilot survey "tab" entries to another symbol (string combination), 
#so that we can use online translation tools to easily translate the survey

# %%
import os
import pandas as pd

# %%
fileName = "RdP_FOSH_20180923_form_responses_1_copy.tsv"
filePath = "/home/andre/Documents/repositories/amchagas/map_fosh_demand/survey/answers/"

# %%
test = open(filePath+fileName)
dummie = test.readlines()
test.close()

# %%
print(type(dummie[0]))
print(dummie)
# Out:
# <class 'str'>
# ...

# %%
for i in range(len(dummie)):
    dummie[i] = dummie[i].replace("\t"," X ")
    #dummie[i] = dummie[i].replace("'","\"")

# %%
test = open(filePath+fileName[0:-4]+"_new_tab.tsv","w")
for i in range(len(dummie)):
    test.write(dummie[i])
    
test.close()

# %%
test = open(filePath+fileName[0:-4]+"_new_tab.tsv")
dummie = test.readlines()
test.close()

# %%
dummie
# Out:
# ['Timestamp X Sexo: X Idade (em anos) X País: X Estado: X Cidade: X Escolaridade: X Formação: X Possui vínculo com alguma instituição? X Se sim, qual o nome dessa instituição? (opcional) X Ocupação: X Qual destas é a sua área principal (Grande Área)? X Há quantos anos você atua nessa área? X Qual é a sua sub-área? X Você utiliza técnologias abertas na pesquisa? X Você conhece alguém que utiliza tecnologias abertas na pesquisa? X Você conhece alguma iniciativa ou equipamento que seja open source e desenvolvido para uso laboratorial? X Como você percebe o acesso à equipamentos para a pesquisa dentro da sua instituição? X Caso considere que existam dificuldades relacionadas ao acesso à equipamentos, na sua opinião, qual seria a maior barreira? X Poderia em algumas palavras, nos dizer a razão? X Qual(is) equipamento(s) o seu laboratório mais usa / necessita? X Algum projeto já teve de ser alterado por falta de acesso a equipamentos? X Se sim, qual equipamento causou a alteração no projet
# ...
